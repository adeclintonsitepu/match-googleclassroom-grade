# %% [markdown]
# # Buka File di Direktori

# %%
import pandas as pd
import numpy as np

# Database (File Excel) untuk menyimpan nilai final
dataset =  pd.read_excel('2021_D3TI_daftar_mahasiswa.xlsx')

# Daftar nilai
nilai = pd.read_csv('Angkatan 2021\Pemrograman_Mobile_I.csv')

# %% [markdown]
# # Membersihkan data

# %%
# Ubah semua huruf alamat email menjadi huruf kecil
nilai = nilai.rename(columns={'Email Address': 'Alamat Email'}) # Ubah nama header 'Email Address' menjadi 'Alamat Email' jika perlu
dataset['Email'] = dataset['Email'].str.lower()
nilai['Alamat Email'] = nilai['Alamat Email'].str.lower()

# mendapatkan daftar header nilai
nilai_head = list(nilai.columns)
dataset_head = list(dataset.columns)

# tambahkan kolom kosong baru seperti nilai absensi, tugas dll
dataset = dataset.reindex(columns = dataset.columns.tolist() + nilai_head[3:])
dataset
# Out:
#     No        NIM                       Nama                           Email  \
# 0    1  202102001            ALBERT MANURUNG            abetmanroe@gmail.com
# 1    2  202102002        AMELIA USMI ANGGITA                             NaN
# 2    3  202102003              FEBRIANI ZEGA        febrianizega20@gmail.com
# 3    4  202102004           FERIYANTO HALAWA     feriyantohalawa60@gmail.com
# 4    5  202102005           HOTNITA SIHOTANG     nitagracesihotang@gmail.com
# 5    6  202102006     MAULANA MUHAMMAD FAJAR                             NaN
# 6    7  202102007          NISKARNIWATI GULO          niskargulo26@gmail.com
# 7    7  202102007          NISKARNIWATI GULO           niskargulo9@gmail.com
# 8    8  202102008           NURMALIA SIREGAR    nurmaliasiregar791@gmail.com
# 9    9  202102009        SARAH SOPIANA PURBA        sarahsopiana43@gmail.com
# 10  10  202102010          SEPTIAN HARIYANTO            goolbola17@gmail.com
# 11  10  202102010          SEPTIAN HARIYANTO    septianhariyanto15@gmail.com
# 12  11  202102011              NUR AINA SARI        ainasarisari50@gmail.com
# 13  12  202102012                DEDY WIJAYA                             NaN
# 14  13  202102013           ARIWIBOWO HALAWA             arhal3456@gmail.com
# 15  14  202102014  HOTNIEL JAYA PENDI HAREFA        hotnielharefa5@gmail.com
# 16  15  202102015               KASIHANI ZAI            sihanizhay@gmail.com
# 17  16  202102016    REVINA YANTI RAJAGUKGUK       revinayanti2002@gmail.com
# 18  16  202102016    REVINA YANTI RAJAGUKGUK             riowilly1@gmail.com
# 19  16  202102016    REVINA YANTI RAJAGUKGUK         revinayanti20@gmail.com
# 20  16  202102016    REVINA YANTI RAJAGUKGUK  revinarajagukguk1999@gmail.com
# 21  17  202102017   BRUNO INGAT TRIUS NDRURU           brunondruru@gmail.com
# 22  18  202102018                RAMA HALAWA          ramahalawa20@gmail.com
#
#     Absensi Pertemuan 01  Absensi Pertemuan 02  Absensi Pertemuan 03  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
# 17                   NaN                   NaN                   NaN
# 18                   NaN                   NaN                   NaN
# 19                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 22                   NaN                   NaN                   NaN
#
#     Absensi Pertemuan 04  Tugas Mandiri 1  Absensi Pertemuan 05  Bonus Sesi I  \
# 0                    NaN              NaN                   NaN           NaN
# 1                    NaN              NaN                   NaN           NaN
# 2                    NaN              NaN                   NaN           NaN
# 3                    NaN              NaN                   NaN           NaN
# 4                    NaN              NaN                   NaN           NaN
# 5                    NaN              NaN                   NaN           NaN
# 6                    NaN              NaN                   NaN           NaN
# 7                    NaN              NaN                   NaN           NaN
# 8                    NaN              NaN                   NaN           NaN
# 9                    NaN              NaN                   NaN           NaN
# 10                   NaN              NaN                   NaN           NaN
# 11                   NaN              NaN                   NaN           NaN
# 12                   NaN              NaN                   NaN           NaN
# 13                   NaN              NaN                   NaN           NaN
# 14                   NaN              NaN                   NaN           NaN
# 15                   NaN              NaN                   NaN           NaN
# 16                   NaN              NaN                   NaN           NaN
# 17                   NaN              NaN                   NaN           NaN
# 18                   NaN              NaN                   NaN           NaN
# 19                   NaN              NaN                   NaN           NaN
# 20                   NaN              NaN                   NaN           NaN
# 21                   NaN              NaN                   NaN           NaN
# 22                   NaN              NaN                   NaN           NaN
#
#     Absensi Pertemuan 06  Tugas Mandiri 2  UTS (Ujian Tengah Semester)
# 0                    NaN              NaN                          NaN
# 1                    NaN              NaN                          NaN
# 2                    NaN              NaN                          NaN
# 3                    NaN              NaN                          NaN
# 4                    NaN              NaN                          NaN
# 5                    NaN              NaN                          NaN
# 6                    NaN              NaN                          NaN
# 7                    NaN              NaN                          NaN
# 8                    NaN              NaN                          NaN
# 9                    NaN              NaN                          NaN
# 10                   NaN              NaN                          NaN
# 11                   NaN              NaN                          NaN
# 12                   NaN              NaN                          NaN
# 13                   NaN              NaN                          NaN
# 14                   NaN              NaN                          NaN
# 15                   NaN              NaN                          NaN
# 16                   NaN              NaN                          NaN
# 17                   NaN              NaN                          NaN
# 18                   NaN              NaN                          NaN
# 19                   NaN              NaN                          NaN
# 20                   NaN              NaN                          NaN
# 21                   NaN              NaN                          NaN
# 22                   NaN              NaN                          NaN

# %% [markdown]
# # Mencocokkan Data

# %%
# yang berisi NaN tidak perlu dibandingkan
periksa_dataset = dataset['Email'].isnull()

for i in range(0,len(dataset)):
    if(~periksa_dataset[i]):
        for j in range(0,len(nilai)):
            if(dataset['Email'][i]==nilai['Alamat Email'][j]):
                for k in range(3,len(nilai_head)):
                    dataset[nilai_head[k]][i] = nilai[nilai_head[k]][j]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23408\3722169574.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[nilai_head[k]][i] = nilai[nilai_head[k]][j]

# %%
dataset
# Out:
#     No        NIM                       Nama                           Email  \
# 0    1  202102001            ALBERT MANURUNG            abetmanroe@gmail.com
# 1    2  202102002        AMELIA USMI ANGGITA                             NaN
# 2    3  202102003              FEBRIANI ZEGA        febrianizega20@gmail.com
# 3    4  202102004           FERIYANTO HALAWA     feriyantohalawa60@gmail.com
# 4    5  202102005           HOTNITA SIHOTANG     nitagracesihotang@gmail.com
# 5    6  202102006     MAULANA MUHAMMAD FAJAR                             NaN
# 6    7  202102007          NISKARNIWATI GULO          niskargulo26@gmail.com
# 7    7  202102007          NISKARNIWATI GULO           niskargulo9@gmail.com
# 8    8  202102008           NURMALIA SIREGAR    nurmaliasiregar791@gmail.com
# 9    9  202102009        SARAH SOPIANA PURBA        sarahsopiana43@gmail.com
# 10  10  202102010          SEPTIAN HARIYANTO            goolbola17@gmail.com
# 11  10  202102010          SEPTIAN HARIYANTO    septianhariyanto15@gmail.com
# 12  11  202102011              NUR AINA SARI        ainasarisari50@gmail.com
# 13  12  202102012                DEDY WIJAYA                             NaN
# 14  13  202102013           ARIWIBOWO HALAWA             arhal3456@gmail.com
# 15  14  202102014  HOTNIEL JAYA PENDI HAREFA        hotnielharefa5@gmail.com
# 16  15  202102015               KASIHANI ZAI            sihanizhay@gmail.com
# 17  16  202102016    REVINA YANTI RAJAGUKGUK       revinayanti2002@gmail.com
# 18  16  202102016    REVINA YANTI RAJAGUKGUK             riowilly1@gmail.com
# 19  16  202102016    REVINA YANTI RAJAGUKGUK         revinayanti20@gmail.com
# 20  16  202102016    REVINA YANTI RAJAGUKGUK  revinarajagukguk1999@gmail.com
# 21  17  202102017   BRUNO INGAT TRIUS NDRURU           brunondruru@gmail.com
# 22  18  202102018                RAMA HALAWA          ramahalawa20@gmail.com
#
#    Absensi Pertemuan 01 Absensi Pertemuan 02 Absensi Pertemuan 03  \
# 0                 100.0                100.0                100.0
# 1                   NaN                  NaN                  NaN
# 2                 100.0                100.0                100.0
# 3                 100.0                100.0                100.0
# 4                   NaN                  NaN                  NaN
# 5                   NaN                  NaN                  NaN
# 6                 100.0                100.0                100.0
# 7                   NaN                  NaN                  NaN
# 8                 100.0                100.0                100.0
# 9                   NaN                  0.0                 90.0
# 10                  NaN                  NaN                  NaN
# 11                100.0                100.0                100.0
# 12                100.0                100.0                100.0
# 13                  NaN                  NaN                  NaN
# 14                  NaN                  NaN                  NaN
# 15                  NaN                  NaN                  NaN
# 16                100.0                  0.0                  0.0
# 17                  NaN                  NaN                  NaN
# 18                  NaN                  NaN                  NaN
# 19                  NaN                  NaN                  NaN
# 20                  NaN                  NaN                  NaN
# 21                  NaN                  NaN                  NaN
# 22                100.0                  0.0                100.0
#
#    Absensi Pertemuan 04  Tugas Mandiri 1 Absensi Pertemuan 05 Bonus Sesi I  \
# 0                 100.0              NaN                100.0          0.0
# 1                   NaN              NaN                  NaN          NaN
# 2                 100.0              NaN                100.0          1.0
# 3                 100.0              NaN                100.0          0.0
# 4                   NaN              NaN                  NaN          NaN
# 5                   NaN              NaN                  NaN          NaN
# 6                 100.0              NaN                100.0          0.0
# 7                   NaN              NaN                  NaN          NaN
# 8                 100.0              NaN                100.0          0.0
# 9                   0.0              NaN                  0.0          0.0
# 10                  NaN              NaN                  NaN          NaN
# 11                100.0              NaN                100.0          0.0
# 12                100.0              NaN                100.0          0.0
# 13                  NaN              NaN                  NaN          NaN
# 14                  NaN              NaN                  NaN          NaN
# 15                  NaN              NaN                  NaN          NaN
# 16                  0.0              NaN                  0.0          0.0
# 17                  NaN              NaN                  NaN          NaN
# 18                  NaN              NaN                  NaN          NaN
# 19                  NaN              NaN                  NaN          NaN
# 20                  NaN              NaN                  NaN          NaN
# 21                  NaN              NaN                  NaN          NaN
# 22                100.0              NaN                100.0          1.0
#
#    Absensi Pertemuan 06  Tugas Mandiri 2  UTS (Ujian Tengah Semester)
# 0                   0.0              NaN                          NaN
# 1                   NaN              NaN                          NaN
# 2                 100.0              NaN                          NaN
# 3                 100.0              NaN                          NaN
# 4                   NaN              NaN                          NaN
# 5                   NaN              NaN                          NaN
# 6                 100.0              NaN                          NaN
# 7                   NaN              NaN                          NaN
# 8                 100.0              NaN                          NaN
# 9                   0.0              NaN                          NaN
# 10                  NaN              NaN                          NaN
# 11                100.0              NaN                          NaN
# 12                100.0              NaN                          NaN
# 13                  NaN              NaN                          NaN
# 14                  NaN              NaN                          NaN
# 15                  NaN              NaN                          NaN
# 16                  0.0              NaN                          NaN
# 17                  NaN              NaN                          NaN
# 18                  NaN              NaN                          NaN
# 19                  NaN              NaN                          NaN
# 20                  NaN              NaN                          NaN
# 21                  NaN              NaN                          NaN
# 22                  0.0              NaN                          NaN

# %%
dataset = dataset.reindex(sorted(dataset.columns), axis=1)

first_cols = dataset_head[:4]
last_cols = [col for col in dataset.columns if col not in first_cols]

dataset = dataset[first_cols+last_cols]

# %%
dataset.to_excel("output.xlsx")

# writer = pd.ExcelWriter('output.xlsx',
#                         engine='xlsxwriter',
#                         options={'strings_to_numbers': True})
